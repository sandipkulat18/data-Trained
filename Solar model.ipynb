# %%
from IPython.display import display,HTML

# %%
import pandas as pd

# %%
df=pd.read_csv('solar_copy.csv')

# %%
df
# Out:
#          v1      v2      v3      v4      v5      v6      v7      v8      v9  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df.columns
# Out:
# Index(['v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10', 'v11',
#        'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20', 'v21',
#        'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'v29', 'v30', 'v31',
#        'v32', 'v33', 'v34', 'v35', 'v36', 'v37', 'v38', 'v39', 'v40', 'v41',
#        'v42', 'v43', 'v44', 'v45', 'v46', 'v47', 'v48', 'v49', 'v50', 'v51',
#        'v52', 'v53', 'v54', 'v55', 'v56', 'v57', 'v58', 'v59', 'v60', 'v61'],
#       dtype='object')

# %%
df.tail(5)
# Out:
#          v1      v2      v3      v4      v5      v6      v7      v8      v9  \
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#         v10  ...     v52     v53     v54     v55     v56     v57     v58  \
# 202  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 203  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 204  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 205  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 206  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#         v59     v60  v61
# 202  0.0193  0.0157    M
# ...

# %%
df
# Out:
#          v1      v2      v3      v4      v5      v6      v7      v8      v9  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.describe()
# Out:
#                v1          v2          v3          v4          v5          v6  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                v7          v8          v9         v10  ...         v51  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
pd.set_option('display.max_rows',62)

# %%
df
# Out:
#          v1      v2      v3      v4      v5      v6      v7      v8      v9  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.dtypes
# Out:
# v1     float64
# v2     float64
# v3     float64
# v4     float64
# v5     float64
# v6     float64
# v7     float64
# v8     float64
# v9     float64
# v10    float64
# v11    float64
# v12    float64
# v13    float64
# v14    float64
# v15    float64
# v16    float64
# v17    float64
# v18    float64
# v19    float64
# v20    float64
# v21    float64
# v22    float64
# v23    float64
# v24    float64
# v25    float64
# v26    float64
# v27    float64
# v28    float64
# v29    float64
# v30    float64
# v31    float64
# v32    float64
# v33    float64
# v34    float64
# v35    float64
# v36    float64
# v37    float64
# v38    float64
# v39    float64
# v40    float64
# v41    float64
# v42    float64
# v43    float64
# v44    float64
# v45    float64
# v46    float64
# v47    float64
# v48    float64
# v49    float64
# v50    float64
# v51    float64
# v52    float64
# v53    float64
# v54    float64
# v55    float64
# v56    float64
# v57    float64
# v58    float64
# ...

# %%
True+True
# Out:
# 2

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#      count      mean       std     min      25%     50%      75%     max
# v1   207.0  0.029208  0.023038  0.0015  0.01330  0.0228  0.03580  0.1371
# v2   207.0  0.038443  0.033040  0.0006  0.01640  0.0308  0.04810  0.2339
# v3   207.0  0.043837  0.038521  0.0015  0.01890  0.0342  0.05820  0.3059
# v4   207.0  0.054053  0.046583  0.0058  0.02445  0.0441  0.06570  0.4264
# v5   207.0  0.075105  0.055669  0.0067  0.03770  0.0620  0.10105  0.4010
# v6   207.0  0.104599  0.059247  0.0102  0.06695  0.0921  0.13415  0.3823
# v7   207.0  0.121591  0.061897  0.0033  0.08060  0.1056  0.15305  0.3729
# v8   207.0  0.134677  0.085340  0.0055  0.08035  0.1119  0.16980  0.4590
# v9   207.0  0.177361  0.118311  0.0075  0.09675  0.1522  0.23150  0.6828
# v10  207.0  0.208245  0.134741  0.0113  0.11115  0.1810  0.26900  0.7106
# v11  207.0  0.236376  0.132923  0.0289  0.12820  0.2251  0.30180  0.7342
# v12  207.0  0.250666  0.140264  0.0236  0.13345  0.2497  0.33160  0.7060
# ...

# %%
df.describe(include=['O'])
# Out:
#         v61
# count   207
# unique    2
# top       M
# freq    111

# %%
df['v61'].describe()
# Out:
# count     207
# unique      2
# top         M
# freq      111
# Name: v61, dtype: object

# %%
df=pd.DataFrame.rename(df,columns={'v61':'Class'})

# %%
df
# Out:
#          v1      v2      v3      v4      v5      v6      v7      v8      v9  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.title('Null _values')
plt.show()

# %%
df['Class'].hist(grid=False)
plt.title('Rock Vs Mine')
plt.show()

# %%
pd.DataFrame(df)
# Out:
#          v1      v2      v3      v4      v5      v6      v7      v8      v9  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df['Class'].value_counts()
# Out:
# M    111
# R     96
# Name: Class, dtype: int64

# %%
df['Class'].hist(grid=True)
plt.title('Rock Vs Mine')
plt.show()

# %%
df['Class'].value_counts(normalize=True)*100
# Out:
# M    53.623188
# R    46.376812
# Name: Class, dtype: float64

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()
df['Class']=LE.fit_transform(df['Class'])

# %%
df.caveat() in official documentation of pandas
# Out:
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_2076\1400273790.py", line 1
#     df.caveat() in official documentation of pandas
#                             ^
# SyntaxError: invalid syntax

# %%
df.Class.value_counts()
# Out:
# 0    111
# 1     96
# Name: Class, dtype: int64

# %%
LE.inverse_transform([1,0])
# Out:
# array(['R', 'M'], dtype=object)

# %%
LE.inverse_transform([0,1])
# Out:
# array(['M', 'R'], dtype=object)

# %%
LE.inverse_transform([1])
# Out:
# array(['R'], dtype=object)

# %%
df.corr()
# checking correletion
# Out:
#              v1        v2        v3        v4        v5        v6        v7  \
# v1     1.000000  0.736104  0.571706  0.490853  0.345744  0.238824  0.262095
# v2     0.736104  1.000000  0.779915  0.607297  0.419877  0.332319  0.279328
# v3     0.571706  0.779915  1.000000  0.782662  0.546365  0.346271  0.190628
# v4     0.490853  0.607297  0.782662  1.000000  0.729338  0.352901  0.248713
# v5     0.345744  0.419877  0.546365  0.729338  1.000000  0.597438  0.334831
# v6     0.238824  0.332319  0.346271  0.352901  0.597438  1.000000  0.703624
# v7     0.262095  0.279328  0.190628  0.248713  0.334831  0.703624  1.000000
# v8     0.356312  0.334747  0.237974  0.248131  0.203590  0.471942  0.675612
# v9     0.356822  0.317929  0.253615  0.252048  0.176522  0.329145  0.469490
# v10    0.318440  0.270787  0.219641  0.238136  0.183240  0.288639  0.425675
# v11    0.343362  0.297186  0.274751  0.270466  0.232939  0.333560  0.398590
# ...

# %%
corr_mat=df.corr()
plt.figure(figsize=(80,80))
sns.heatmap(corr_mat,annot=True)
plt.title('correltion_Matrix')
plt.savefig('correltion_Matrix.jpg')
plt.show()

# %%
corr_matrix=df.corr()
corr_matrix['Class'].sort_values(ascending=False)
# Out:
# Class    1.000000
# v36      0.262727
# v35      0.220761
# v37      0.203826
# v34      0.165523
# v31      0.121008
# v33      0.105149
# v32      0.059882
# v40      0.037101
# v38      0.034187
# v17      0.006070
# v30      0.000364
# v16     -0.008246
# v57     -0.010152
# v18     -0.011635
# v41     -0.013833
# v25     -0.025284
# v26     -0.026867
# v29     -0.037543
# v15     -0.051240
# v27     -0.055324
# v39     -0.061572
# v24     -0.071733
# v28     -0.085259
# v60     -0.086982
# v55     -0.094392
# v7      -0.117848
# v23     -0.123539
# v59     -0.132088
# v6      -0.132172
# v56     -0.138112
# v19     -0.138648
# v53     -0.139288
# v42     -0.144705
# v14     -0.151116
# v58     -0.185066
# v50     -0.185623
# v54     -0.186932
# v8      -0.191424
# v3      -0.192589
# v22     -0.199643
# v20     -0.223143
# v5      -0.224809
# v2      -0.231670
# v43     -0.236109
# v21     -0.242818
# v4      -0.247935
# v1      -0.270482
# v44     -0.284527
# v52     -0.284528
# ...

# %% [markdown]
# # Lets check the data distubution allong all the column

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=True,fontsize=1,figsize=(18,12))
plt.show()

# %%
df.skew()
# Out:
# v1       2.122983
# v2       2.149965
# v3       2.645849
# v4       3.397590
# v5       2.020369
# v6       1.243828
# v7       0.977346
# v8       1.482755
# v9       1.654558
# v10      1.278532
# v11      0.980388
# v12      0.580918
# v13      0.730580
# v14      1.028081
# v15      0.761921
# v16      0.687003
# v17      0.648143
# v18      0.518349
# v19      0.282680
# v20     -0.089670
# v21     -0.253902
# v22     -0.398178
# v23     -0.605569
# v24     -0.698045
# v25     -0.787297
# v26     -0.673803
# v27     -0.625869
# v28     -0.608543
# v29     -0.438803
# v30     -0.142382
# v31      0.265875
# v32      0.304906
# v33      0.429747
# v34      0.576483
# v35      0.602241
# v36      0.631304
# v37      0.691936
# v38      1.051649
# v39      0.920842
# v40      0.856537
# v41      0.866684
# v42      0.858517
# v43      0.911296
# v44      1.258602
# v45      1.371554
# v46      1.700582
# v47      1.783552
# v48      1.287541
# v49      1.266425
# v50      1.776935
# ...

# %%
x=df.drop('Class',axis=1)
y=df['Class']

# %%
x
# Out:
#          v1      v2      v3      v4      v5      v6      v7      v8      v9  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 202    0
# 203    0
# 204    0
# 205    0
# 206    0
# Name: Class, Length: 207, dtype: int32

# %%
#checking skweness
x.skew().sort_values(ascending=False)
# Out:
# v4     3.397590
# v60    2.769687
# v51    2.724246
# v3     2.645849
# v2     2.149965
# v1     2.122983
# v52    2.098458
# v58    2.094443
# v5     2.020369
# v56    1.810948
# v47    1.783552
# v55    1.782651
# v50    1.776935
# v59    1.736231
# v46    1.700582
# v57    1.685823
# v9     1.654558
# v8     1.482755
# v45    1.371554
# v48    1.287541
# v10    1.278532
# v49    1.266425
# v44    1.258602
# v6     1.243828
# v54    1.102569
# v53    1.053124
# v38    1.051649
# v14    1.028081
# v11    0.980388
# v7     0.977346
# v39    0.920842
# v43    0.911296
# v41    0.866684
# v42    0.858517
# v40    0.856537
# v15    0.761921
# v13    0.730580
# v37    0.691936
# v16    0.687003
# v17    0.648143
# v36    0.631304
# v35    0.602241
# v12    0.580918
# v34    0.576483
# v18    0.518349
# v33    0.429747
# v32    0.304906
# v19    0.282680
# v31    0.265875
# v20   -0.089670
# v30   -0.142382
# v21   -0.253902
# v22   -0.398178
# v29   -0.438803
# v23   -0.605569
# ...

# %% [markdown]
# # power transformation method

# %%
from sklearn.preprocessing import power_transform,PowerTransformer

# %%
pt=PowerTransformer()

# %%
x_new_pt=pt.fit_transform(x)

# %%
x_new_pt
# Out:
# array([[ 1.08912924,  0.80129701,  1.34591864, ..., -0.39407823,
#         -0.33359159, -0.33938838],
#        [ 0.16157567,  0.96711777,  1.70366359, ...,  1.45407103,
#          0.59395038,  0.60688916],
#        [-1.18957919, -0.73009627,  0.88311685, ..., -0.53212969,
#         -0.67059398,  1.30186704],
#        ...,
#        [ 1.31195981,  0.52153537, -0.83064834, ...,  1.19810333,
#          0.25267881, -0.81960248],
#        [ 0.40876623,  0.19704233,  0.50292447, ...,  0.30455525,
#         -0.79208771, -0.20645355],
#        [ 0.14869962,  0.23864008, -1.0887507 , ..., -0.76780528,
#         -0.10574389,  1.2737208 ]])

# %%
x_new=power_transform(x)

# %%
x_new
# Out:
# array([[ 1.08912924,  0.80129701,  1.34591864, ..., -0.39407823,
#         -0.33359159, -0.33938838],
#        [ 0.16157567,  0.96711777,  1.70366359, ...,  1.45407103,
#          0.59395038,  0.60688916],
#        [-1.18957919, -0.73009627,  0.88311685, ..., -0.53212969,
#         -0.67059398,  1.30186704],
#        ...,
#        [ 1.31195981,  0.52153537, -0.83064834, ...,  1.19810333,
#          0.25267881, -0.81960248],
#        [ 0.40876623,  0.19704233,  0.50292447, ...,  0.30455525,
#         -0.79208771, -0.20645355],
#        [ 0.14869962,  0.23864008, -1.0887507 , ..., -0.76780528,
#         -0.10574389,  1.2737208 ]])

# %%
pd.DataFrame(x_new,columns=x.columns).skew().sort_values(ascending=False)
# Out:
# v58    0.223876
# v60    0.202180
# v1     0.200933
# v2     0.199141
# v57    0.198659
# v55    0.189963
# v3     0.189890
# v4     0.187191
# v45    0.173040
# v46    0.171332
# v59    0.169458
# v52    0.148039
# v5     0.143413
# v49    0.133036
# v53    0.129131
# v54    0.127815
# v17    0.123958
# v47    0.122300
# v56    0.119415
# v50    0.107588
# v37    0.102334
# v16    0.101293
# v48    0.097960
# v18    0.092734
# v36    0.088722
# v38    0.086910
# v44    0.081035
# v39    0.080050
# v51    0.079630
# v35    0.078587
# v9     0.076941
# v10    0.074818
# v15    0.068989
# v41    0.061999
# v42    0.050499
# v34    0.048270
# v11    0.047279
# v8     0.041090
# v6     0.040183
# v14    0.038737
# v40    0.035722
# v43    0.033234
# v12    0.032338
# v13    0.025071
# v33    0.021297
# v19    0.019557
# v7     0.018700
# v32    0.003969
# v31   -0.001084
# v30   -0.048147
# v20   -0.075836
# v21   -0.108058
# v29   -0.134171
# v22   -0.146903
# v24   -0.166348
# ...

# %%
x.columns
# Out:
# Index(['v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10', 'v11',
#        'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20', 'v21',
#        'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'v29', 'v30', 'v31',
#        'v32', 'v33', 'v34', 'v35', 'v36', 'v37', 'v38', 'v39', 'v40', 'v41',
#        'v42', 'v43', 'v44', 'v45', 'v46', 'v47', 'v48', 'v49', 'v50', 'v51',
#        'v52', 'v53', 'v54', 'v55', 'v56', 'v57', 'v58', 'v59', 'v60'],
#       dtype='object')

# %% [markdown]
# #checking outlier

# %%
x.iloc[:,0:30].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#plotiing rest all the columns
x.iloc[:,30:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# # let quantify

# %%
import numpy as np
from scipy.stats import zscore
(np.abs(zscore(x))).all().all()
# Out:
# True

# %%
(np.abs(zscore(x))>3).all().all()
# Out:
# False

# %%
zscore(x)
# Out:
#            v1        v2        v3        v4        v5        v6        v7  \
# 0    0.700189  0.420421  1.052950  0.319501  0.777810  2.600518  1.522475
# 1   -0.130894  0.599427  1.719130  1.167351  0.401466  2.087862  1.967839
# 2   -0.835792 -0.647546  0.480451 -0.722021 -0.983262 -1.147115 -0.190961
# 3    2.044717  0.854283  0.110929 -0.315311 -0.289998 -0.671681 -0.011196
# 4   -0.026465  0.208041 -0.419933 -0.788730 -0.660939 -0.094732 -0.024152
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.457236 -0.116596 -0.703580 -0.782275 -0.644733  0.988106  1.315179
# 203  0.134531 -0.859926 -0.365285  0.050513  0.016119 -0.148874 -0.365867
# 204  1.000424  0.159497 -0.672353 -0.534806 -0.720362  0.211508  0.066541
# 205  0.047506 -0.095358  0.134350  0.145196 -1.051689  0.521132  0.403398
# 206 -0.139596 -0.065018 -0.786852 -0.577844 -0.967056 -1.197873 -0.908401
#
#            v8        v9       v10  ...       v51       v52       v53  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2076\1450638155.py in <module>
# ----> 1 np.abs()
#
# TypeError: absolute() takes from 1 to 2 positional arguments but 0 were given

# %%
(zscore(x)<3).all().all()
# Out:
# False

# %% [markdown]
# # No outlier are present in my data

# %%
#Training process being
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,roc_curve,roc_auc_score
from sklearn.metrics import classification_report,confusion_matrix

# %%
maxAccu=0
maxRS=0
for i in range(1,2000):
    x_train,x_text,y_train,y_text=train_test_split(x,y,test_size=.20,random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    predrf=lr.predict(x_text)
    acc=accuracy_score(y_text,predrf)
    print('testing accurancy',acc,'random_state',i)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
    print('max_accurancy',maxAccu,'max_random_state',i)
# Out:
# testing accurancy 0.8095238095238095 random_state 1
# max_accurancy 0.8095238095238095 max_random_state 1
# testing accurancy 0.8095238095238095 random_state 2
# max_accurancy 0.8095238095238095 max_random_state 2
# testing accurancy 0.7142857142857143 random_state 3
# max_accurancy 0.8095238095238095 max_random_state 3
# testing accurancy 0.6904761904761905 random_state 4
# max_accurancy 0.8095238095238095 max_random_state 4
# testing accurancy 0.8095238095238095 random_state 5
# max_accurancy 0.8095238095238095 max_random_state 5
# testing accurancy 0.7619047619047619 random_state 6
# max_accurancy 0.8095238095238095 max_random_state 6
# testing accurancy 0.7142857142857143 random_state 7
# max_accurancy 0.8095238095238095 max_random_state 7
# testing accurancy 0.8095238095238095 random_state 8
# max_accurancy 0.8095238095238095 max_random_state 8
# testing accurancy 0.7619047619047619 random_state 9
# max_accurancy 0.8095238095238095 max_random_state 9
# ...

# %%
print('Best accuracy is',maxAccu, 'On random state',maxRS)
# Out:
# Best accuracy is 0.9761904761904762 On random state 1147

# %%
x_train,x_text,y_train,y_text=train_test_split(x,y,test_size=.20,random_state=1147)

# %%
x_train.shape
# Out:
# (165, 60)

# %%
x_text.shape
# Out:
# (42, 60)

# %%
y_train.shape
# Out:
# (165,)

# %%
y_text.shape
# Out:
# (42,)

# %% [markdown]
# # Logistics regression

# %% [markdown]
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier

# %%
lr.fit(x_train,y_train)
predlr=lr.predict(x_text)
print('Accurancy',accuracy_score(y_text,predlr)*100)
print(confusion_matrix(y_text,predlr))
print(classification_report(y_text,predlr))
# Out:
# Accurancy 97.61904761904762
# [[25  0]
#  [ 1 16]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.94      0.97        17
#
#     accuracy                           0.98        42
#    macro avg       0.98      0.97      0.98        42
# weighted avg       0.98      0.98      0.98        42

# %% [markdown]
# # Decission Tree

# %% [markdown]
# from sklearn.tree import DecisionTreeClassifier
# dt=DecisionTreeClassifier()
# dt.fit(x_train,y_train)
# preddt=dt.predict(x_text)
# pred_train_dtc=dt.predict(x_train)
# print('Testing Accurancy',accuracy_score(y_text,preddt)*100)# testing accurancy
# print('Training Accurancy',accuracy_score(y_train,pred_train_dtc)*100)# training accuarncy
# print(confusion_matrix(y_text,predlr))
# print(classification_report(y_text,predlr))

# %% [markdown]
# # Rondom forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_text)

print('Testing Accurancy',accuracy_score(y_text,predrf)*100)# testing accurancy

print(confusion_matrix(y_text,predrf))
print(classification_report(y_text,predrf))
# Out:
# Testing Accurancy 95.23809523809523
# [[25  0]
#  [ 2 15]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        25
#            1       1.00      0.88      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.96      0.94      0.95        42
# weighted avg       0.96      0.95      0.95        42

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt=dt.predict(x_text)
pred_train_dtc=dt.predict(x_train)
print('Testing Accurancy',accuracy_score(y_text,preddt)*100)# testing accurancy
print('Training Accurancy',accuracy_score(y_train,pred_train_dtc)*100)# training accuarncy
print(confusion_matrix(y_text,preddt))
print(classification_report(y_text,preddt))
# Out:
# Testing Accurancy 80.95238095238095
# Training Accurancy 100.0
# [[22  3]
#  [ 5 12]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85        25
#            1       0.80      0.71      0.75        17
#
#     accuracy                           0.81        42
#    macro avg       0.81      0.79      0.80        42
# weighted avg       0.81      0.81      0.81        42

# %%
rf
# Out:
# RandomForestClassifier()

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svc=SVC()

svc.fit(x_train,y_train)
ad_predt=svc.predict(x_text)

print('Accurancy',accuracy_score(y_text,ad_predt)*100)# testing accurancy

print(confusion_matrix(y_text,predlr))
print(classification_report(y_text,predlr))
# Out:
# Accurancy 97.61904761904762
# [[25  0]
#  [ 1 16]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.94      0.97        17
#
#     accuracy                           0.98        42
#    macro avg       0.98      0.97      0.98        42
# weighted avg       0.98      0.98      0.98        42

# %% [markdown]
# # cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
#validation Accurancy
cr_1=cross_val_score(lr,x,y,cv=5)
print('cross validation score of logistic regresion model:',cr_1.mean())
# Out:
# cross validation score of logistic regresion model: 0.6332171893147502

# %%
cr_1
# Out:
# array([0.4047619 , 0.78571429, 0.63414634, 0.85365854, 0.48780488])

# %%
cr_2=cross_val_score(dt,x,y,cv=5,)
print('cross validation score of logistic regresion model:',cr_1.mean())
# Out:
# cross validation score of logistic regresion model: 0.6332171893147502

# %%
cr_2
# Out:
# array([0.47619048, 0.71428571, 0.63414634, 0.82926829, 0.70731707])

# %%
cr_3=cross_val_score(rf,x,y,cv=5,)
print('cross validation score of logistic regresion model:',cr_3.mean())
# Out:
# cross validation score of logistic regresion model: 0.6912891986062718

# %%
cr_3
# Out:
# array([0.54761905, 0.73809524, 0.70731707, 0.82926829, 0.63414634])

# %%
cr_4=cross_val_score(svc,x,y,cv=5,)
print('cross validation score of logistic regresion model:',cr_4.mean())
# Out:
# cross validation score of logistic regresion model: 0.5550522648083623

# %%
cr_3
# Out:
# array([0.54761905, 0.73809524, 0.70731707, 0.82926829, 0.63414634])

# %% [raw]
# cr_4

# %%
cr_4
# Out:
# array([0.45238095, 0.76190476, 0.43902439, 0.73170732, 0.3902439 ])

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'max_features':['auto','sqrt','log2'],
          'max_depth':[4,5,6,7,8],
          'criterion':['gini','entropy'],
          'n_estimators':[100,200,300,400,500]}

# %%
3*5*2*5*7
# Out:
# 1050

# %%
GVC=GridSearchCV(estimator=RandomForestClassifier(),param_grid=parameter,cv=7,scoring='accuracy')

# %%
GVC.fit(x_train,y_train)
GVC.best_params_

# %%
type(GVC)

# %%
Randbest_params_sifierndomForestClassifierC.best_params_

# %%
GVC_pred=GVC.best_estimator_.predict(x_text)
accuracy_score(y_text,GVC_pred)

# %% [markdown]
# # ROC AUC Plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GVC.best_estimator_,x_text,y_text)
plot.title("ROC AUC Curve")
plt.show()

# %%
import joblib
joblib.dump(GVC.best_estimator_,'Sonarmode.pkl')

# %%
saving =10
saving
